# %% [markdown]
# ### DS6600 Lab 1
# #### Madelyn Mathai

# %% [markdown]
# ##### 1. https://github.com/mathaim/DS6600_lab1

# %% [markdown]
# ##### 2. Virtual Environment

# %% [markdown]
# ##### (a) In a raw cell (find the box in JupyterLab that allows you to select Code, Markdown,or Raw), copy and paste everything that appears in the Pipfile that was automatically generated by pipenv . [1 point]

# %% [raw]
# [[source]]
# url = "https://pypi.org/simple"
# verify_ssl = true
# name = "pypi"
#
# [packages]
# numpy = "==1.25.2"
# pandas = "==2.0.3"
# requests = "==2.31.0"
# matplotlib = "==3.7.2"
# ipykernel = "==6.25.1"
# jupyter = "*"
# jupyterlab = "==4.0.5"
#
# [dev-packages]
#
# [requires]
# python_version = "3.11.4"

# %% [markdown]
# ##### (b) In VS Code, connect to the kernel attached to this virtual environment. In a code cell, type !python --version to display the version number of Python running in this virtual environment. [1 point]

# %%
# !python --version
# Out:
# Python 3.11.4

# %% [markdown]
# ##### (c) In a code cell, import numpy , pandas , matplotlib , and requests to demonstrate that they can all be loaded without error. [1 point]

# %%
import numpy
import pandas
import matplotlib
import requests

# %% [markdown]
# ##### (d) In a code cell, import sklearn and display the error to show that it has not been installed. [1 point]

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# #### 3. Describe, in words, whether a virtual machine, a container, a virtual environment, or the global environment of a single computer is best suited for each of the following situations. Be clear about why the option you choose works best, and also about why the other options are insufficient or are overkill.

# %% [markdown]
# ##### (a) Meals on Wheels Beyond Charlottesville
# For this scenario, I believe a virtual machine would be the best environment to expand Charlottesville Meals on Wheels' signup portal and mobile app to other chapters. Every chapter will have their own database of volunteers and clients, so we require a large amount of storage and it must be accessible through an internet connection. A virtual machine allows for full control of the Python version and packages as well as the installation of other software like database management systems, which we will require here. It also allows us to choose different physical resources to increase the storage and computational speed of the system. While we need to be extremely careful of scammers trying to steal our credentials using a VM, I figure if we are important enough to implement technology for a national nonprofit organization, security is something we need to be on top of anyways.
#
# We wouldn't want to go with a global environment because your code will be specific to your paticular computer's setup and other chapters won't be able to reproduce results easily. If someone at another chapter has different packages/versions installed, the code will break. We also wouldn't want to go with a virtual environment because while it allows for control of Python and packages, it still operates under your particular computer's operating system. Therefore, if we created our web portal and app on a Mac, there is no guarantee it will work on a Windows machine. I considered a container, but given that we need to scale this project across the country, I don't think a container would be best because it still depends on my computer's computation hardware. A container is limited by my computer's processor, which won't work with the scale of this project.

# %% [markdown]
# ##### (b) Legal Aid Justice Center
# In this scenario, I think it makes the most sense to use a virtual environment. This is important data that is going to a nonprofit, so it is generally a good idea to keep everything organized in its own file. It is also good to be forward looking and if they ever request data from the government again, it would be nice to rerun the code to clean it. A virtual environment allows us to specify versions of Python and its packages in a well documented way.
#
# Even though the nature of the request is a one time report and there is no need to share code, I think a global environment would be a bit too messy given the importance of the client. I suppose if my involvement with the Legal Aid Justice Center was truly a one time thing and then I would never work with them or problems like this again, I could do it in a global environment and make sure to keep everything organized. A container is unecessary because the size of the data is not large, it does not need to be easily reproducible by others, and it is not computationally intensive. Following the same reasoning, a virtual machine is also unnecessary. A virtual machine also poses a potential security threat from scammers and this is incredibly sensitive data.

# %% [markdown]
# ##### (c) Save the Children
# For this scenario, I believe a virtual machine would be the best environment to build a predictive model that can be deployed by several different people working for Save the Children. A virtual machine allows for full control of the Python version and packages as well as the installation of other software like database management systems, which we will require here. It also allows us to choose different physical resources to increase the storage and computational speed of the system. I will also require software packages that only work in Ubuntu Linix, which means I will need to change my computer's operating system. This would be accomplished with either a container or a virtual machine. While we need to be extremely careful of scammers trying to steal our credentials using a VM, I figure if we are important enough to implement technology for aN international NGO, security is something we need to be on top of anyways.
#
# We wouldn't want to go with a global environment because your code will be specific to your paticular computer's setup and other chapters won't be able to reproduce results easily. If someone at another chapter has different packages/versions installed, the code will break. We also wouldn't want to go with a virtual environment because while it allows for control of Python and packages, it still operates under your particular computer's operating system. Therefore, if we created our web portal and app on a Mac, there is no guarantee it will work on a Windows machine. I considered a container, but given that we need to scale this project across the country, I don't think a container would be best because it still depends on my computer's computation hardware. A container is limited by my computer's processor, which won't work with the scale of this project.

# %% [markdown]
# ##### (d) Swedish Python
# For this scenario, I think a virtual environment would be best. If the only thing I care about is the version of Python on my current project, this can easily be controlled in a virtual environment.
#
# A global environment change would impact all my work. I am okay with relearning Python in Swedish for my other projects, so there is no need to work in a global environment and limit the Python version. This does not relate to scale of the project, operating systems, physical resources, or reproducibility of my code, so there is no need for a container or a virtual machine.
